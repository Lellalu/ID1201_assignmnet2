# %%
import matplotlib.pyplot as plt
from google.colab import files

# %%
x = list(pow(2,i) for i in range(0,21))
linear_unsort_time = [179.2, 150.0, 170.7, 224.9, 266.8, 491.7, 758.4, 1287.8, 2512.5, 4579.2, 6366.5, 7149.7, 9225.1, 18479.0, 35612.5, 15729.2, 12445.7, 23445.9, 47175.2, 93162.5, 188621.0]
linear_sort_time = [170.8, 158.5, 170.6, 237.4, 324.9, 583.3, 958.5, 1716.6, 3354.1, 6471.0, 5983.4, 6062.5, 9629.3, 18829.1, 38212.5, 21520.8, 23095.9, 43820.8, 89529.3, 175954.1, 349299.9]
binary_time = [208.5, 212.5, 208.7, 250.0, 262.5, 329.3, 329.0, 337.3, 425.2, 354.3, 437.5, 404.1, 737.5, 466.7, 1287.4, 1174.9, 1224.9, 1299.9, 2587.5, 2612.6, 5437.7]


plt.plot(x, linear_unsort_time, label = "search_unsorted")
plt.plot(x, linear_sort_time, label = "search_sorted")
plt.plot(x, binary_time, label = "binary_search")
plt.legend()
plt.title("Result of searchBenchmark")
plt.xlabel("Array length")
plt.ylabel("Average running time (ns)")
plt.yscale('log')
plt.savefig('searchBenchmark.png', dpi=600)
plt.show()
files.download('searchBenchmark.png')

# %%
x = list(pow(2,i) for i in range(0,21))
linear_unsort_time = [229.0, 212.0, 420.0, 670.0, 666.0, 2246.0, 2729.0, 4862.0, 15654.0, 32054.0, 9879.0, 45974.0, 35070.0, 89175.0, 73499.0, 40433.0, 109225.0, 82820.0, 165170.0, 432937.0, 830246.0]
linear_sort_time = [308.0, 325.0, 562.0, 791.0, 679.0, 1233.0, 983.0, 1075.0, 1745.0, 2458.0, 454.0, 1041.0, 650.0, 741.0, 408.0, 779.0, 2287.0, 1754.0, 3170.0, 3375.0, 5345.0]
binary_time = [199.0, 233.0, 354.0, 396.0, 283.0, 433.0, 358.0, 329.0, 474.0, 500.0, 404.0, 712.0, 441.0, 591.0, 274.0, 462.0, 912.0, 733.0, 1154.0, 1308.0, 1229.0]


plt.plot(x, linear_unsort_time, label = "duplicateSearchLinear")
plt.plot(x, linear_sort_time, label = "duplicateSearchBinary")
plt.plot(x, binary_time, label = "duplicateSearchBetter")
plt.legend()
plt.title("Result of duplicateBenchmark")
plt.xlabel("Array length")
plt.ylabel("Average running time (ns)")
plt.yscale('log')
plt.savefig('duplicateBenchmark.png', dpi=600)
plt.show()
files.download('duplicateBenchmark.png')
